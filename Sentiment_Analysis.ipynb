# %% [markdown]
# ## Making Sentiment Analysis Better with NLTK & Scikit-Learn
#
# So you might be asking, what exactly is "sentiment analysis"?
#
# Well, it's exactly what it sounds like: it's building a computational system to determine the emotional tone behind words. This is important because it allows you to gain an understanding of the attitudes, opinions, and emotions of the people in your data. At a higher level, sentiment analysis involves Natural language processing and artificial intelligence by taking the actual text element, transforming it into a format that a machine can read, and using statistics to determine the actual sentiment.

# %%
import re
import nltk
from sklearn.feature_extraction.text import CountVectorizer  
from sklearn.model_selection import train_test_split 
# if this doesn't work, try: from sklearn.cross_validation import train_test_split

# %% [markdown]
# # 1. Building Sentiment Classifier using Scikit-Learn package

# %% [markdown]
# ### Preparing the Data
#
# To implement our linear classifier, we need the twitter data in a format that allows us to feed it into the classifier. Using the `sklearn.feature_extraction.text.CountVectorizer`, we will convert the text documents to a matrix of token counts. As you'll see soon enough, these vector counts will be what the classifier will ultimately use to train. So first, we import all the needed modules:

# %%
text_pos = []
labels_pos = []
with open("/Users/anushachirukuri/Desktop/data/pos_tweets.txt") as f:
    for i in f: 
        text_pos.append(i) 
        labels_pos.append('pos')

text_neg = []
labels_neg = []
with open("/Users/anushachirukuri/Desktop/data/neg_tweets.txt") as f:
    for i in f: 
        text_neg.append(i)
        labels_neg.append('neg')

# %%
training_text = text_pos[:int((.8)*len(text_pos))] + text_neg[:int((.8)*len(text_neg))]
training_labels = labels_pos[:int((.8)*len(labels_pos))] + labels_neg[:int((.8)*len(labels_neg))]

test_text = text_pos[int((.8)*len(text_pos)):] + text_neg[int((.8)*len(text_neg)):]
test_labels = labels_pos[int((.8)*len(labels_pos)):] + labels_neg[int((.8)*len(labels_neg)):]

# %% [markdown]
# Next, we initialize a vectoriser with the CountVectorizer class. Because we haven't pre-processed any of the data, we'll set lowercase to `False` and exclude stop word removal or stemming.

# %%
vectorizer = CountVectorizer(
    analyzer = 'word',
    lowercase = False,
    max_features = 85
)

# %% [markdown]
# Next, we use the `fit_transform()` method to transform our corpus data into feature vectors. Since the input needed is a list of strings, we concatenate all of our training and test data.

# %%
features = vectorizer.fit_transform(
    training_text + test_text)

features_nd = features.toarray() # for easy use

# %% [markdown]
# As a final step, we'll split the training data to get an evaluation set through scikit-learn's built-in cross validation method. All we need to do is provide the data and assign a training percentage (in this case, 80%).

# %%
x_train, x_test, y_train, y_test  = train_test_split(
        features_nd[0:len(training_text)], 
        training_labels,
        train_size=0.80, 
        random_state=1234)

# %% [markdown]
# ### Building Model - Linear Classifier
#
# Finally, we can build the classifier for this corpus! As mentioned before, we'll be using the Logistic Regression from scikit-learn, so we'll start there:

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()

# %% [markdown]
# Once the model is initialized, we have to fit it to our specific dataset, so we use scikit-learn's `fit()` method to do so:

# %%
log_model = log_model.fit(x_train, y_train)
# Out:
# /Users/anushachirukuri/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# And finally, we use this classifier to label the evaluation set we created earlier:

# %%
test_pred = log_model.predict(x_test)

# %% [markdown]
# ### Tesing Model Accuracy

# %% [markdown]
# Now just for our own "fun", let's take a look at some of the classifications our model makes! We'll choose a random set and then call our model on each!

# %%
import random
spl = random.sample(range(len(test_pred)), 10)
for text, sentiment in zip(test_text, test_pred[spl]):
    print (sentiment, text)
# Out:
# neg "Love that the Obamas are bringing back date night. Men, take note  http://bit.ly/ebPBZ"
#
# neg "loves chocolate milk  and that is GF YEAH.."
#
# neg "loving life... and loving you "
#
# neg "Lunch date with @Londonmitch to go to Leathenhall Market's cheese shop was really nice "
#
# neg "Made my evening: Starbucks barista complimented me on my hamsa scarf. When he heard I designed it and sell them on etsy he was "
#
# pos "Matt came to visit!  canton with him for dinner then prolly stopping somewhere for drinks and the cavs "
#
# neg "May be going to London next week "
#
# neg "me and rosa are going 2 start our own youtube channel! i'm super excited that we get 2 share our RaNdOmNeSs with the world!!!! "
#
# neg "Modern warfare 2 gameplay looks goood  #xboxe3"
#
# neg "Momz just made it back from Vegas, yayyyyy! "

# %% [markdown]
# Just glancing over the examples above, it's pretty obvious there are some misclassifications. But obviously we want to do more than just 'eyeball' the data, so let's actually calculate the accuracy score.

# %% [markdown]
# What's the point in creating a machine learning algorithm if you have no idea how it performs? This is why we left some of the dataset for testing purposes. In scikit-learn, there is a function called sklearn.metrics.accuracy_score which calculates the accuracy percentage. Using this, we see that this model has an accuracy of about 76%.

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, test_pred))
# Out:
# 0.7601246105919003

# %% [markdown]
# # 2. Building Sentiment Classifier using NLTK package

# %% [markdown]
# ### Preparing the Data
#
# `nltk` is a much different from `scikit-learn`. `nltk` specializes and is *made for* natural language processing tasks, so needless to say, it was expected that `scikit-learn` wouldn't necessarily be the best choice.
#
# With that said, we'll now use `nltk` to build a sentiment analysis model on the same dataset. `nltk` requires a different data format, which is why I've implemented the function below:

# %%
import nltk
nltk.download('punkt')

def format_sentence(sent):
    return({word: True for word in nltk.word_tokenize(sent)})
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/anushachirukuri/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
print(format_sentence("The cat is very cute"))
# Out:
# {'The': True, 'cat': True, 'is': True, 'very': True, 'cute': True}

# %%
import io
pos = []
with io.open("/Users/anushachirukuri/Desktop/data/pos_tweets.txt", 'rU', encoding='utf-8') as f:
    for i in f: 
        pos.append([format_sentence(i), 'pos'])
# Out:
# /Users/anushachirukuri/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: 'U' mode is deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
neg = []
with io.open("/Users/anushachirukuri/Desktop/data/neg_tweets.txt", 'rU', encoding='utf-8') as f:
    for i in f: 
        neg.append([format_sentence(i), 'neg'])
# Out:
# /Users/anushachirukuri/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: 'U' mode is deprecated

# %% [markdown]
# Next, we'll split the labeled data into the training and test data, just as we did before.

# %%
training = pos[:int((.8)*len(pos))] + neg[:int((.8)*len(neg))]
test = pos[int((.8)*len(pos)):] + neg[int((.8)*len(neg)):]

# %% [markdown]
# ### Building a Classifier
#
# All NLTK classifiers work with feature structures, which can be simple dictionaries mapping a feature name to a feature value. In this example, we use the Naive Bayes Classifier, which makes predictions based on the word frequencies associated with each label of positive or negative.

# %%
from nltk.classify import NaiveBayesClassifier

classifier = NaiveBayesClassifier.train(training)

# %% [markdown]
# Since the Naive Bayes Classifier is based entirely off of the frequencies associated with each label for a given word, we can call a function `show_most_informative_features()` to see which words are the highest indicators of a positive or negative label:

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#                       no = True              neg : pos    =     19.4 : 1.0
#                     love = True              pos : neg    =     19.0 : 1.0
#                  awesome = True              pos : neg    =     17.2 : 1.0
#                 headache = True              neg : pos    =     16.2 : 1.0
#                       Hi = True              pos : neg    =     12.7 : 1.0
#                      fan = True              pos : neg    =      9.7 : 1.0
#                      New = True              pos : neg    =      9.7 : 1.0
#                    Thank = True              pos : neg    =      9.7 : 1.0
#                beautiful = True              pos : neg    =      9.7 : 1.0
#                     haha = True              pos : neg    =      9.3 : 1.0

# %% [markdown]
# Notice that there are three columns. Column 1 is why we used `format_sentence()` to map each word to a `True` value. What it does is count the number of occurences of each word for both labels to compute the ratio between the two, which is what column 3 represents. Column 2 lets us know which label occurs more frequently (the label on the left is the label most associated with the corresponding word.

# %% [markdown]
# ### Classification
#
# Just to see how our model works, let's try the classifier out with a positive example:

# %%
example1 = "Twilio is an awesome company!"

print(classifier.classify(format_sentence(example1)))
# Out:
# pos

# %% [markdown]
# Now let's try out an example we'd expect a negative label:

# %%
example2 = "I'm sad that Twilio doesn't have even more blog posts!"

print(classifier.classify(format_sentence(example2)))
# Out:
# neg

# %% [markdown]
# So what happens when we mix words of different sentiment labels? Let's take a look at this example:

# %%
example3 = "I have no headache!"

print(classifier.classify(format_sentence(example3)))
# Out:
# neg

# %% [markdown]
# And we've found a mislabel! Naive Bayes doesn't consider the relationship *between* words, which is why it wasn't able to catch the fact that "no" acted as a negator to the word `headache`. Instead, it read two negative indicators and classified it as such.
#
# Given that, we can probably expect a less than perfect accuracy rate.

# %% [markdown]
# ### Accuracy
#
# Just like `scikit-learn`, nltk has a built in method that computes the accuracy rate of our model:

# %%
from nltk.classify.util import accuracy
print(accuracy(classifier, test))
# Out:
# 0.8308457711442786

# %% [markdown]
# And we have improved performance! Awesome. Now, 83% is fairly solid, but it could be better! If you look at the actual data, you'll see that the data is kind of messy - there are typos, abbreviations, grammatical errors of all sorts. So how do we handle that? Can we handle that? Stay tuned for more soon.

# %% [markdown]
# # 3. Validating Classifier Output using Count and Visualization

# %%
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anushachirukuri/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/anushachirukuri/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### In this case we are validating text_pos (positive data) from the above examples

# %%
textfile = []
with open("/Users/anushachirukuri/Desktop/data/pos_tweets.txt") as f:
    for i in f:
        textfile.append(i) 

words = nltk.word_tokenize(str(textfile))

# %% [markdown]
# ### Preprocessing data to remove stop words

# %%
default_stopwords = stopwords.words('english')
default_stopwords.extend(['...','\'re','n\'t','\'the','\'this','\'it','n\'',
                         'it\\','\'1\\ti','\'0\\ti','\'0\\tda','.\\n','..\\n',
                         '1\\ti','\'1\\tthe'])

# %%
# Remove single-character tokens (mostly punctuation)
words = [word for word in words if len(word) > 2]

# Remove numbers
# words = [word for word in words if not word.isnumeric()]

# Lowercase all words (default_stopwords are lowercase too)
words = [word.lower() for word in words]

# Stemming words seems to make matters worse, disabled
# stemmer = nltk.stem.snowball.SnowballStemmer('german')
# words = [stemmer.stem(word) for word in words]

# Remove stopwords
words = [word for word in words if word not in default_stopwords]

# %% [markdown]
# ### Display Frequency count for dataset

# %%
# Calculate frequency distribution
fdist = nltk.FreqDist(words)

# Output top 50 words

for word, frequency in fdist.most_common(10):
    print(u'{};{}'.format(word, frequency))
# Out:
# love;67
# good;58
# day;45
# lakers;40
# taylor;40
# new;38
# great;33
# see;33
# going;33
# swift;33

# %% [markdown]
# ### Visualizing the Frequency Count

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white')
wordcloud.generate_from_frequencies(frequencies=fdist)

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %% [markdown]
# ##### Reading a Txt file and analysing the sentiment.

# %%
from IPython.display import display, HTML
import pandas as pd

file1 = []
file1_sentiment = []
with open("/Users/anushachirukuri/Desktop/data/textsample1.txt") as f:
    for line in f:
        file1_sentiment.append(line.rstrip()+"\t"+classifier.classify(format_sentence(line)))

df = pd.DataFrame([x.split('\t') for x in file1_sentiment], columns=["A","Sentence", "Sentiment"])
df.to_csv("/Users/anushachirukuri/Desktop/data/text1_sentiment.txt", sep='\t')
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>Sentence</th>
#       <th>Sentiment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>The Da Vinci Code book is just awesome.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>this was the first clive cussler i've ever read, but even books like Relic, and Da Vinci code were more plausible than this.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>i liked the Da Vinci Code a lot.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>i liked the Da Vinci Code a lot.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>I liked the Da Vinci Code but it ultimatly didn't seem to hold it's own.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1</td>
#       <td>that's not even an exaggeration ) and at midnight we went to Wal-Mart to buy the Da Vinci Code, which is amazing of course.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1</td>
#       <td>I loved the Da Vinci Code, but now I want something better and different!..</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1</td>
#       <td>i thought da vinci code was great, same with kite runner.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1</td>
#       <td>The Da Vinci Code is actually a good movie...</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1</td>
#       <td>I thought the Da Vinci Code was a pretty good book.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1</td>
#       <td>The Da Vinci Code is one of the most beautiful movies ive ever seen.</td>
#       <td>neg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1</td>
#       <td>The Da Vinci Code is an * amazing * book, do not get me wrong.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1</td>
#       <td>then I turn on the light and the radio and enjoy my Da Vinci Code.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1</td>
#       <td>The Da Vinci Code was REALLY good.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1</td>
#       <td>i love da vinci code....</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>1</td>
#       <td>i loved da vinci code..</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1</td>
#       <td>TO NIGHT:: THE DA VINCI CODE AND A BEAUTIFUL MIND...</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1</td>
#       <td>THE DA VINCI CODE is AN AWESOME BOOK....</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1</td>
#       <td>Thing is, I enjoyed The Da Vinci Code.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1</td>
#       <td>very da vinci code slash amazing race.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>1</td>
#       <td>Hey I loved The Da Vinci Code!..</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1</td>
#       <td>also loved the da vinci code..</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1</td>
#       <td>I really enjoyed the Da Vinci Code but thought I would be disappointed in the other books &amp; # 8230;.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1</td>
#       <td>I do like Angels and Demons more then The Da Vinci Code.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>1</td>
#       <td>The Da Vinci Code was a really good movie.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1</td>
#       <td>yeah, da vinci code is an awesome movie i liked it pretty interesting.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>1</td>
#       <td>I really like The Da Vinci Code.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>1</td>
#       <td>Da Vinci Code is amazing.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1</td>
#       <td>The Da Vinci Code was awesome...</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>1</td>
#       <td>The Da Vinci Code's backtory on various religious historical figures and such were interesting at times, but I'm more of scifi girl at heart.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>1</td>
#       <td>Book ( s ): I love The Da Vinci Code..</td>
#       <td>neg</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>1</td>
#       <td>And then we went to see The Da Vinci Code, which was CRAZY awesome and Ian McKellen is my old, gay husband.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>1</td>
#       <td>" Now some people will say to me, Joe, I liked the Da Vinci code, you're being too hard on Dan Brown.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>1</td>
#       <td>I love the da vinci code...</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>1</td>
#       <td>Well I did enjoy Bridget Jones and I loved the Da Vinci Code so this idea appeals to me and it takes Chick Lit into one of the few arenas that the genre has yet to explore...</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>1</td>
#       <td>I just read Da Vinci Code ( which was AWESOME by the way )  .</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>1</td>
#       <td>The Da Vinci Code is excellent if you read it as normal as you read other novels,,,..</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>1</td>
#       <td>I loved the Da Vinci Code!</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>1</td>
#       <td>I love reading The Da Vinci Code!!!!</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>1</td>
#       <td>I'm telling you, the Da Vinci Code is an AWESOME book!</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>1</td>
#       <td>Then again, my opinion may be a bit biased because I loved the Da Vinci Code soundtrack. ).</td>
#       <td>neg</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>1</td>
#       <td>And I was quite pleased with my own open-mindedness, after having loved The Da Vinci Code so much, that I was able to get equal enjoyment " seeing how the other side reads.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>1</td>
#       <td>I love the Da Vinci Code.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>1</td>
#       <td>Da Vinci code is awesome!</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>1</td>
#       <td>The Da Vinci Code is awesome.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>1</td>
#       <td>The Da Vinci Code is SUCH an awesome book!</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>1</td>
#       <td>I LOVE THE DA VINCI CODE...</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>1</td>
#       <td>I loved The Da Vinci Code.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>1</td>
#       <td>the da vinci code is awesome!</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>1</td>
#       <td>oh so beautiful Da Vinci Code...</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>1</td>
#       <td>i loved the da vinci code.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>1</td>
#       <td>The Da Vinci Code is an awesome book.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>1</td>
#       <td>Da vinci code is an awesome book.</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>1</td>
#       <td>I miss ripping acoustic music and the Da Vinci Code...</td>
#       <td>pos</td>

# %%
from nltk.classify import NaiveBayesClassifier
from nltk.classify.util import accuracy

data = []
with open("/Users/anushachirukuri/Desktop/data/textsample1.txt") as f:
    for line in f:
        sent , txt = line.split('\t')
        data.append([format_sentence(txt), 'pos' if int(sent) == 1 else 'neg'])
 
  
random.shuffle(data)
training_data = data[:int((.8)*len(data))]
test_data = data[int((.8)*len(data)):] 

classifier = NaiveBayesClassifier.train(training_data)
classifier.show_most_informative_features()

print(accuracy(classifier, test_data))
# Out:
# Most Informative Features
#                      You = True              neg : pos    =    761.0 : 1.0
#                    MOVIE = True              neg : pos    =    456.6 : 1.0
#                        A = True              neg : pos    =    290.5 : 1.0
#                    NC-17 = True              neg : pos    =    273.9 : 1.0
#                        ' = True              neg : pos    =    273.9 : 1.0
#                     hate = True              neg : pos    =    207.5 : 1.0
#                        * = True              neg : pos    =    207.5 : 1.0
#                       by = True              neg : pos    =     91.3 : 1.0
#                    about = True              neg : pos    =     41.5 : 1.0
#                        ) = True              neg : pos    =     31.9 : 1.0
# 0.7278401997503121

# %% [markdown]
# Analysis : we got accuracy as 74% as the textfile1 contains typos, abbreviations, grammatical errors.We can further improve the accuracy by removing the stop words.

# %%
from nltk.classify import NaiveBayesClassifier
from nltk.classify.util import accuracy

data = []
with open("/Users/anushachirukuri/Desktop/data/textsample1.txt") as f:
    for line in f:
        sent , txt = line.split('\t')
        data.append([format_sentence(txt), 'pos' if int(sent) == 1 else 'neg'])

with open("/Users/anushachirukuri/Desktop/data/textsample2.txt") as f:
    for line in f:
        sent , txt = line.split('\t')
        data.append([format_sentence(txt), 'pos' if int(sent) == 1 else 'neg'])    
  
random.shuffle(data)
training_data = data[:int((.8)*len(data))]
test_data = data[int((.8)*len(data)):] 

classifier = NaiveBayesClassifier.train(training_data)
classifier.show_most_informative_features()

print(accuracy(classifier, test_data))
# Out:
# Most Informative Features
#                   sucked = True              neg : pos    =    284.0 : 1.0
#                  awesome = True              pos : neg    =    280.3 : 1.0
#                     love = True              pos : neg    =    118.0 : 1.0
#                      guy = True              neg : pos    =    110.9 : 1.0
#                       Oh = True              neg : pos    =    110.0 : 1.0
#                     hate = True              neg : pos    =    104.5 : 1.0
#                    heard = True              neg : pos    =     65.7 : 1.0
#                   person = True              neg : pos    =     60.4 : 1.0
#                   friday = True              neg : pos    =     59.6 : 1.0
#                       My = True              neg : pos    =     57.8 : 1.0
# 0.973943661971831

# %%
We see the Accuracy as 97% when training model is given both textsample1 and textsample2 files
